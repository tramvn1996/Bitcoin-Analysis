# %%
import pandas as pd
import datetime
import numpy as np

# %%
vendor = pd.read_csv("data.csv")

# %%
vendor.head()
# Out:
#   category  created_on  lattitude   longitude            name  venue_id
# 0      atm  1465943680  50.122064   -5.532898     One And All      8225
# 1  default  1397211665  60.160534   24.939049   Belle Modeste        42
# 2  grocery  1394219130  48.437747 -123.312411   Slaters Meats        15
# 3  default  1422120857  50.065833   14.358897   kaktusy eshop        33
# 4     food  1370785480  51.549378   -0.059379  Pembury Tavern         3

# %%
vendor['created_on'][1]
vendor['created_date'] = pd.to_datetime(vendor['created_on'],unit='s')
vendor['date'] = vendor['created_date'].astype(str).str[:10]

# %%
cat = vendor.category

# %%
type(cat)
# Out:
# pandas.core.series.Series

# %%
vendor.head()
# Out:
#   category  created_on  lattitude   longitude            name  venue_id  \
# 0      atm  1465943680  50.122064   -5.532898     One And All      8225
# 1  default  1397211665  60.160534   24.939049   Belle Modeste        42
# 2  grocery  1394219130  48.437747 -123.312411   Slaters Meats        15
# 3  default  1422120857  50.065833   14.358897   kaktusy eshop        33
# 4     food  1370785480  51.549378   -0.059379  Pembury Tavern         3
#
#          created_date        date
# 0 2016-06-14 22:34:40  2016-06-14
# 1 2014-04-11 10:21:05  2014-04-11
# 2 2014-03-07 19:05:30  2014-03-07
# 3 2015-01-24 17:34:17  2015-01-24
# 4 2013-06-09 13:44:40  2013-06-09

# %%
ven_count = vendor.groupby('date')['name'].nunique()

# %%
ven_count
# Out:
# date
# 2013-02-28     1
# 2013-03-03     1
# 2013-03-04     1
# 2013-04-13     1
# 2013-04-14     8
# 2013-04-15     3
# 2013-04-16     1
# 2013-04-17     1
# 2013-04-18     4
# 2013-04-19     1
# 2013-04-20     1
# 2013-04-21     1
# 2013-04-22     3
# 2013-04-23     1
# 2013-04-24     1
# 2013-04-28     5
# 2013-04-29     1
# 2013-04-30     1
# 2013-05-01     1
# 2013-05-02     1
# 2013-05-03     2
# 2013-05-04     1
# 2013-05-06     1
# 2013-05-08     1
# 2013-05-09     1
# 2013-05-13     2
# 2013-05-16     1
# 2013-05-23     1
# 2013-05-25     1
# 2013-05-28     2
#               ..
# 2018-01-24    11
# 2018-01-25    12
# 2018-01-26    10
# 2018-01-27     7
# 2018-01-28     8
# 2018-01-29    16
# 2018-01-30    11
# 2018-01-31    10
# 2018-02-01    10
# 2018-02-02     8
# 2018-02-03     6
# 2018-02-04     1
# 2018-02-05    17
# 2018-02-06     9
# 2018-02-07    12
# 2018-02-08     5
# 2018-02-09    12
# 2018-02-10     2
# 2018-02-11     2
# 2018-02-12     4
# 2018-02-13    12
# ...

# %%
type(ven_count)
# Out:
# pandas.core.series.Series

# %%
ven_count = ven_count.to_frame()

# %%
ven_count.reset_index()
# Out:
#             date  name
# 0     2013-02-28     1
# 1     2013-03-03     1
# 2     2013-03-04     1
# 3     2013-04-13     1
# 4     2013-04-14     8
# 5     2013-04-15     3
# 6     2013-04-16     1
# 7     2013-04-17     1
# 8     2013-04-18     4
# 9     2013-04-19     1
# 10    2013-04-20     1
# 11    2013-04-21     1
# 12    2013-04-22     3
# 13    2013-04-23     1
# 14    2013-04-24     1
# 15    2013-04-28     5
# 16    2013-04-29     1
# 17    2013-04-30     1
# 18    2013-05-01     1
# 19    2013-05-02     1
# 20    2013-05-03     2
# 21    2013-05-04     1
# 22    2013-05-06     1
# 23    2013-05-08     1
# 24    2013-05-09     1
# 25    2013-05-13     2
# 26    2013-05-16     1
# 27    2013-05-23     1
# 28    2013-05-25     1
# 29    2013-05-28     2
# ...          ...   ...
# 1579  2018-01-24    11
# 1580  2018-01-25    12
# 1581  2018-01-26    10
# 1582  2018-01-27     7
# 1583  2018-01-28     8
# 1584  2018-01-29    16
# 1585  2018-01-30    11
# 1586  2018-01-31    10
# ...

# %%
ven_count.shape
# Out:
# (1609, 1)

# %%
ven_count['total']=ven_count['name']
i=1
while i<1609:
    ven_count['total'][i]= ven_count['name'][i]+ven_count['total'][i-1]
    i+=1

# %%
ven_count.head()
# Out:
#             name  total
# date
# 2013-02-28     1      1
# 2013-03-03     1      2
# 2013-03-04     1      3
# 2013-04-13     1      4
# 2013-04-14     8     12

# %%
ven_count.reset_index()
# Out:
#             date  name  total
# 0     2013-02-28     1      1
# 1     2013-03-03     1      2
# 2     2013-03-04     1      3
# 3     2013-04-13     1      4
# 4     2013-04-14     8     12
# 5     2013-04-15     3     15
# 6     2013-04-16     1     16
# 7     2013-04-17     1     17
# 8     2013-04-18     4     21
# 9     2013-04-19     1     22
# 10    2013-04-20     1     23
# 11    2013-04-21     1     24
# 12    2013-04-22     3     27
# 13    2013-04-23     1     28
# 14    2013-04-24     1     29
# 15    2013-04-28     5     34
# 16    2013-04-29     1     35
# 17    2013-04-30     1     36
# 18    2013-05-01     1     37
# 19    2013-05-02     1     38
# 20    2013-05-03     2     40
# 21    2013-05-04     1     41
# 22    2013-05-06     1     42
# 23    2013-05-08     1     43
# 24    2013-05-09     1     44
# 25    2013-05-13     2     46
# 26    2013-05-16     1     47
# 27    2013-05-23     1     48
# 28    2013-05-25     1     49
# 29    2013-05-28     2     51
# ...

# %%
ven_count = ven_count.cumsum()

# %%
ven_count.plot()

# %%
ven_count.reset_index().to_csv('total_vendor.csv')
